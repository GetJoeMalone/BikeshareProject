# %% [markdown]
# # Pulling in new data from Google Places and Google Maps API
#
# ### In order to enhance the initial bikeshare datasets I am going to add data on places near each bike hub to allow for better analysis of the placement, usage and customer base represented in the bikeshare data

# %%
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup as bs4
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # read csv file into dataframe

# %%
data  = pd.read_csv('new_york_city.csv')
data.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     5688089  2017-06-11 14:55:05  2017-06-11 15:08:21            795
# 1     4096714  2017-05-11 15:30:11  2017-05-11 15:41:43            692
# 2     2173887  2017-03-29 13:26:26  2017-03-29 13:48:31           1325
# 3     3945638  2017-05-08 19:47:18  2017-05-08 19:59:01            703
# 4     6208972  2017-06-21 07:49:16  2017-06-21 07:54:46            329
#
#              Start Station             End Station   User Type  Gender  \
# 0  Suffolk St & Stanton St  W Broadway & Spring St  Subscriber    Male
# 1  Lexington Ave & E 63 St         1 Ave & E 78 St  Subscriber    Male
# 2        1 Pl & Clinton St    Henry St & Degraw St  Subscriber    Male
# 3    Barrow St & Hudson St         W 20 St & 8 Ave  Subscriber  Female
# 4          1 Ave & E 44 St         E 53 St & 3 Ave  Subscriber    Male
#
#    Birth Year
# 0      1998.0
# 1      1981.0
# 2      1987.0
# 3      1986.0
# 4      1992.0

# %% [markdown]
# # Create a list of all start station names

# %%
listOfStartStations = data['Start Station'].unique()
len(listOfStartStations)
listOfStartStations[2] = listOfStartStations[2] + " nyc"
listOfStartStations[2]
# Out:
# '1 Pl & Clinton St nyc'

# %%
listOfStartStations
# Out:
# array(['Suffolk St & Stanton St', 'Lexington Ave & E 63 St',
#        '1 Pl & Clinton St nyc', 'Barrow St & Hudson St',
#        '1 Ave & E 44 St', 'State St & Smith St', 'Front St & Gold St',
#        'E 89 St & York Ave', 'Central Park S & 6 Ave', 'E 3 St & 1 Ave',
#        'Bank St & Washington St', 'Front St & Maiden Ln',
#        'E 10 St & 5 Ave', '1 Ave & E 68 St', 'N 11 St & Wythe Ave',
#        'E 17 St & Broadway', 'E 2 St & Avenue C',
#        'Central Park West & W 76 St', 'W 22 St & 8 Ave',
#        'E 71 St & 1 Ave', 'University Pl & E 14 St', 'E 25 St & 2 Ave',
#        'Dean St & Hoyt St', 'Allen St & Stanton St', 'NYCBS Depot - SSP',
#        'W 26 St & 8 Ave', 'Great Jones St', 'W 43 St & 10 Ave',
#        'Grand St & Elizabeth St', 'W 20 St & 11 Ave', 'Old Fulton St',
#        'Allen St & Hester St', 'E 55 St & 3 Ave', '8 Ave & W 52 St',
#        'Broadway & W 29 St', 'Cathedral Pkwy & Broadway',
#        'Bayard St & Baxter St', 'Driggs Ave & N Henry St',
#        'Perry St & Bleecker St', 'Broadway & E 22 St',
#        'Carmine St & 6 Ave', 'Fulton St & Clermont Ave',
#        'Broadway & W 56 St', '8 Ave & W 16 St', 'W 84 St & Columbus Ave',
#        'E 53 St & Madison Ave', 'W 43 St & 6 Ave', 'Broadway & W 36 St',
#        'Cleveland Pl & Spring St', 'E 45 St & 3 Ave',
#        'Columbus Ave & W 103 St', 'E 39 St & 3 Ave',
#        'Vesey Pl & River Terrace', 'E 39 St & 2 Ave',
#        'Washington St & Gansevoort St', 'E 85 St & 3 Ave',
#        'Avenue D & E 12 St', 'Greenwich St & W Houston St',
#        'W 78 St & Broadway', 'Pier 40 - Hudson River Park',
#        'W 84 St & Broadway', 'Allen St & Rivington St',
#        'E 59 St & Madison Ave', 'Pershing Square South',
#        'Stanton St & Chrystie St', 'E 15 St & 3 Ave',
#        'Front St & Washington St', 'Broadway & W 51 St',
#        'Duane St & Greenwich St', 'Leonard St & Maujer St',
#        'Centre St & Chambers St', '1 Ave & E 16 St',
#        'Reade St & Broadway', 'E 16 St & 5 Ave', 'Barclay St & Church St',
#        'E 33 St & 2 Ave', 'Broadway & Roebling St',
#        'Adelphi St & Myrtle Ave', 'Bergen St & Smith St',
#        '11 Ave & W 41 St', 'University Pl & E 8 St', 'Broadway & W 58 St',
#        'Forsyth St & Broome St', 'Lafayette St & E 8 St',
#        'W 45 St & 8 Ave', 'Bond St & Bergen St', 'Mott St & Prince St',
#        'W 92 St & Broadway', 'E 24 St & Park Ave S',
#        'Central Park West & W 102 St', 'W 42 St & Dyer Ave',
#        'Clinton St & Joralemon St', 'Cooper Square & E 7 St',
#        'Broadway & W 24 St', 'Clinton St & Grand St',
#        'W 13 St & Hudson St', 'Cherry St', 'E 31 St & 3 Ave',
#        'Bus Slip & State St', 'E 6 St & Avenue B',
#        'W Broadway & Spring St', 'Greenwich Ave & 8 Ave',
#        'Kent Ave & N 7 St', 'Sands St & Navy St',
#        'Rivington St & Ridge St', 'E 91 St & Park Ave',
#        '6 Ave & Canal St', '2 Ave & E 31 St', 'W 56 St & 10 Ave',
#        'Henry St & Grand St', 'E 51 St & 1 Ave',
#        'South St & Gouverneur Ln', 'Christopher St & Greenwich St',
#        'E 32 St & Park Ave', 'West St & Chambers St', 'W 49 St & 8 Ave',
#        'Columbia St & Rivington St', 'Centre St & Worth St',
#        'Carroll St & Smith St', 'W 34 St & 11 Ave',
#        'E 66 St & Madison Ave', 'W 13 St & 5 Ave', 'Berkeley Pl & 7 Ave',
#        'MacDougal St & Washington Sq', 'FDR Drive & E 35 St',
#        'W 42 St & 8 Ave', 'E 65 St & 2 Ave', 'Murray St & West St',
#        'President St & Henry St', 'W 38 St & 8 Ave',
#        'Maiden Ln & Pearl St', 'Norfolk St & Broome St',
#        'N 6 St & Bedford Ave', 'Grand Army Plaza & Central Park S',
#        'Washington Pl & 6 Ave', 'E 4 St & 2 Ave', '9 Ave & W 22 St',
#        'W 24 St & 7 Ave', 'Central Park West & W 85 St', 'West Thames St',
#        'W 41 St & 8 Ave', '1 Ave & E 62 St', 'W 14 St & The High Line',
#        'Pershing Square North', 'E 60 St & York Ave',
#        'Cliff St & Fulton St', '3 Ave & E 62 St', 'E 30 St & Park Ave S',
#        '1 Ave & E 94 St', 'Berkeley Pl & 6 Ave', 'W 52 St & 9 Ave',
#        'W 37 St & 10 Ave', 'Driggs Ave & Lorimer St', 'E 55 St & 2 Ave',
#        'E 7 St & Avenue A', '5 Ave & E 93 St', 'Washington Pl & Broadway',
#        'Fulton St & Broadway', 'E 58 St & Madison Ave',
#        'W 87 St  & Amsterdam Ave', 'W 39 St & 9 Ave', '6 Ave & W 33 St',
#        'South End Ave & Liberty St', 'Fulton St & Rockwell Pl',
#        'E 47 St & Park Ave', 'E 12 St & 3 Ave', 'S 4 St & Rodney St',
#        '8 Ave & W 33 St', 'Greenwich St & Hubert St',
#        'Union Ave & Wallabout St', 'Broadway & W 60 St',
#        'W 31 St & 7 Ave', '5 Ave & E 88 St', 'Hudson St & Reade St',
#        '2 Ave & E 99 St', 'MacDougal St & Prince St', 'E 23 St & 1 Ave',
#        '8 Ave & W 31 St', 'Riverside Dr & W 104 St',
#        'W 82 St & Central Park West', 'Columbus Ave & W 72 St',
#        'W 52 St & 11 Ave', 'E 25 St & 1 Ave',
#        'Brooklyn Bridge Park - Pier 2', 'Commerce St & Van Brunt St',
#        'Jackson Ave & 46 Rd', 'W 20 St & 8 Ave',
#        'Mercer St & Bleecker St', 'Throop Ave & Myrtle Ave',
#        'E 81 St & York Ave', 'W 13 St & 6 Ave', 'John St & William St',
#        'Banker St & Meserole Ave', 'York St & Jay St',
#        'Bond St & Schermerhorn St', '5 Ave & E 78 St',
#        'Columbia Heights & Cranberry St', 'E 2 St & Avenue B',
#        'Riverside Dr & W 72 St', 'E 13 St & Avenue A',
#        'E 10 St & Avenue A', 'Myrtle Ave & Lewis Ave',
#        'Murray St & Greenwich St', 'E 33 St & 5 Ave',
#        'Henry St & Poplar St', 'DeKalb Ave & Hudson Ave',
#        'E 2 St & 2 Ave', 'W 18 St & 6 Ave', 'Willoughby St & Fleet St',
#        'Watts St & Greenwich St', 'E 27 St & 1 Ave',
#        'Liberty St & Broadway', 'W 52 St & 6 Ave',
#        'Richardson St & N Henry St', 'Lexington Ave & E 24 St',
#        'Broadway & E 14 St', 'Cadman Plaza West & Montague St',
#        'Rivington St & Chrystie St', 'Central Park W & W 96 St',
#        'W 100 St & Manhattan Ave', 'Graham Ave & Withers St',
#        'W 26 St & 10 Ave', 'Catherine St & Monroe St',
#        'E 5 St & Avenue C', 'W 46 St & 11 Ave',
#        'Graham Ave & Conselyea St', 'E 75 St & 3 Ave', 'W 27 St & 7 Ave',
#        'W 67 St & Broadway', 'E 40 St & 5 Ave', '1 Ave & E 18 St',
#        'E 11 St & 1 Ave', 'Division St & Bowery', 'William St & Pine St',
#        'Court St & State St', 'Broadway & W 41 St', '2 Ave & E 96 St',
#        'Broadway & Berry St', 'Broadway & W 49 St', 'E 35 St & 3 Ave',
#        'LaGuardia Pl & W 3 St', 'E 76 St & 3 Ave',
#        'Emerson Pl & Myrtle Ave', 'Albany Ave & Fulton St',
#        'W 55 St & 6 Ave', 'Little West St & 1 Pl', 'Pike St & E Broadway',
#        'Hanson Pl & Ashland Pl', 'W 74 St & Columbus Ave',
#        'S Portland Ave & Hanson Pl', 'Boerum St & Broadway',
#        'Bushwick Ave & Powers St', 'W 16 St & The High Line',
#        'Greenwich Ave & Charles St', 'DeKalb Ave & S Portland Ave',
#        'E 11 St & Broadway', 'E 84 St & Park Ave', 'Jay St & Tech Pl',
#        'Central Park West & W 68 St', '11 Ave & W 59 St',
#        'Vernon Blvd & 50 Ave', '9 Ave & W 45 St', 'Broadway & W 32 St',
#        'W 17 St & 8 Ave', '45 Rd & 11 St', 'E 6 St & Avenue D',
#        'Water - Whitehall Plaza', '5 Ave & 3 St',
#        'E 55 St & Lexington Ave', 'W 11 St & 6 Ave', '9 Ave & W 18 St',
#        'W 44 St & 5 Ave', 'E 102 St & 1 Ave',
#        'Meserole Ave & Manhattan Ave', 'Monroe St & Classon Ave',
#        'Eckford St & Engert Ave', 'Cadman Plaza E & Tillary St',
#        'Graham Ave & Grand St', 'W 25 St & 6 Ave',
#        'West End Ave & W 107 St', 'Graham Ave & Herbert St',
#        '31 St & Thomson Ave', 'Tompkins Ave & Hopkins St',
#        '11 Ave & W 27 St', 'Macon St & Nostrand Ave',
#        'Pike St & Monroe St', 'W 37 St & 5 Ave', 'Bank St & Hudson St',
#        'Harrison St & Hudson St', 'W 22 St & 10 Ave', 'E 88 St & 1 Ave',
#        'Wythe Ave & Metropolitan Ave', 'Willoughby Ave & Tompkins Ave',
#        'W 106 St & Amsterdam Ave', 'E 19 St & 3 Ave',
#        'Canal St & Rutgers St', 'Avenue D & E 8 St',
#        'Montague St & Clinton St', 'Fulton St & Washington Ave',
#        'Lexington Ave & Classon Ave', 'W 47 St & 10 Ave',
#        'E 48 St & 5 Ave', 'Grand Army Plaza & Plaza St West',
#        'Hancock St & Bedford Ave', 'Amsterdam Ave & W 82 St',
#        '1 Ave & E 78 St', '47 Ave & 31 St', 'E 47 St & 2 Ave',
#        'Amsterdam Ave & W 79 St', 'Central Park West & W 72 St',
#        'E 20 St & Park Ave', 'Spruce St & Nassau St',
#        'Clermont Ave & Lafayette Ave', 'W 21 St & 6 Ave',
#        'Smith St & 9 St', 'Madison St & Clinton St', 'E 9 St & Avenue C',
#        'Metropolitan Ave & Bedford Ave', 'Leonard St & Church St',
#        'N 8 St & Driggs Ave', 'E 48 St & 3 Ave',
#        'Putnam Ave & Throop Ave', 'West End Ave & W 94 St',
#        '5 Ave & E 63 St', 'E 14 St & Avenue B',
#        'W 104 St & Amsterdam Ave', 'W 90 St & Amsterdam Ave',
#        'W 70 St & Amsterdam Ave', 'Sullivan St & Washington Sq',
#        'W 13 St & 7 Ave', 'Baltic St & 5 Ave', 'S 4 St & Wythe Ave',
#        'Atlantic Ave & Furman St', 'W 37 St & Broadway', '14 St & 7 Ave',
#        'Union Ave & Jackson St', 'E 20 St & 2 Ave',
#        'Warren St & Church St', 'South St & Whitehall St',
#        'E 11 St & 2 Ave', 'Queens Plaza North & Crescent St',
#        'Clark St & Henry St', 'Henry St & Degraw St', 'E 52 St & 2 Ave',
#        '1 Ave & E 30 St', 'Nassau Ave & Newell St', 'E 16 St & Irving Pl',
#        'Broadway & W 53 St', 'S 3 St & Bedford Ave',
#        'St Marks Pl & 1 Ave', 'W 27 St & 10 Ave', '5 Ave & E 73 St',
#        'Peck Slip & Front St', 'Metropolitan Ave & Meeker Ave',
#        'W 52 St & 5 Ave', 'Forsyth St & Canal St',
#        'E 68 St & Madison Ave', '3 Ave & E 72 St',
#        'Huron St & Franklin St', 'St Marks Pl & 2 Ave',
#        'Mercer St & Spring St', 'Grand St & Greene St',
#        'Carlton Ave & Flushing Ave', 'Prospect Pl & 6 Ave',
#        '6 Ave & Broome St', 'Carlton Ave & Park Ave',
#        'Bialystoker Pl & Delancey St', 'Riverside Dr & W 78 St',
#        'Broadway & W 37 St', 'Concord St & Bridge St', '3 St & 7 Ave',
#        'W 20 St & 7 Ave', 'Union Ave & N 12 St', '7 Ave & Park Pl',
#        'Bedford Ave & Nassau Ave', 'W 33 St & 7 Ave', 'Smith St & 3 St',
#        'Pearl St & Hanover Square', 'E 58 St & 3 Ave',
#        'E 67 St & Park Ave', 'Union St & Nevins St',
#        'Norman Ave & Leonard St', 'E 81 St & 3 Ave', 'Wyckoff St & 3 Ave',
#        'Broadway & W 55 St', 'Montrose Ave & Bushwick Ave',
#        'Amsterdam Ave & W 73 St', 'Lexington Ave & E 29 St',
#        'Madison Ave & E 82 St', 'Roebling St & N 4 St', 'E 47 St & 1 Ave',
#        'Clinton Ave & Myrtle Ave', 'Henry St & Bay St',
#        'Central Park West & W 100 St', '9 Ave & W 28 St',
#        'E 2 St & 2 Ave E', 'E 91 St & 2 Ave', 'Fulton St & Adams St',
#        'Duffield St & Willoughby St', 'Butler St & Court St',
#        'Stanton St & Mangin St', 'W 63 St & Broadway',
#        '3 St & Prospect Park West', 'McGuinness Blvd & Eagle St',
#        '12 Ave & W 40 St', 'W 53 St & 10 Ave', 'Bedford Ave & S 9 St',
#        'Schermerhorn St & 3 Ave', 'E 84 St & 1 Ave',
#        'Plaza St West & Flatbush Ave', 'E 80 St & 2 Ave',
#        'W 95 St & Broadway', 'Lafayette Ave & St James Pl',
#        'W 4 St & 7 Ave S', 'Clinton St & Union St', 'W 45 St & 6 Ave',
#        'Kosciuszko St & Nostrand Ave', 'Greenwich St & Warren St',
#        'E 72 St & York Ave', 'Pioneer St & Van Brunt St',
#        'Grand St & Havemeyer St', '3 St & 3 Ave', '3 Ave & 14 St',
#        'Laight St & Hudson St', '5 Ave & E 103 St',
#        'E 51 St & Lexington Ave', '3 Ave & E 71 St', 'E 88 St & Park Ave',
#        'Lafayette Ave & Fort Greene Pl', 'Dean St & 4 Ave',
#        'Franklin St & Dupont St', 'Warren St & Court St',
#        'Norman Ave & Leonard St - 2', 'Madison St & Montgomery St',
#        'West Drive & Prospect Park West', 'Columbia St & Kane St',
#        'Clermont Ave & Park Ave', 'Carroll St & 5 Ave',
#        'Clinton St & 4 Place', 'Verona Pl & Fulton St',
#        'Broadway & Battery Pl', 'Degraw St & Smith St',
#        'Lispenard St & Broadway', 'W 100 St & Broadway',
#        'W 59 St & 10 Ave', 'E 95 St & 3 Ave', 'E 58 St & 1 Ave',
#        'Avenue D & E 3 St', 'Nassau Ave & Russell St',
#        'East End Ave & E 86 St', 'Frost St & Meeker St',
#        'W 15 St & 7 Ave', 'E 41 St & Madison Ave',
#        'Scholes St & Manhattan Ave', 'Broadway & W 39 St',
#        'Willoughby Ave & Hall St', 'Richards St & Delavan St',
#        'E 72 St & Park Ave',
#        'Central Park North & Adam Clayton Powell Blvd',
#        'Degraw St & Hoyt St', '12 St & 4 Ave', 'Lafayette St & Jersey St',
#        'W 88 St & West End Ave', 'E 20 St & FDR Drive', 'E 78 St & 2 Ave',
#        'Yankee Ferry Terminal', 'E 97 St & Madison Ave',
#        'E 81 St & Park Ave', '44 Dr & Jackson Ave', 'Union St & 4 Ave',
#        'Fulton St & William St', 'Halsey St & Tompkins Ave',
#        'Columbia St & Degraw St', 'S 5 Pl & S 4 St', 'E 85 St & York Ave',
#        'Garfield Pl & 8 Ave', 'Howard St & Centre St', '5 Ave & E 29 St',
#        'Penn Station Valet', 'Clinton St & Tillary St',
#        'W 76 St & Columbus Ave', 'W 64 St & West End Ave',
#        'Hicks St & Montague St', 'Lawrence St & Willoughby St',
#        'Henry St & Atlantic Ave', 'Marcus Garvey Blvd & Macon St',
#        'Cadman Plaza E & Red Cross Pl', 'Division Ave & Hooper St',
#        'Carroll St & Bond St', 'St James Pl & Oliver St',
#        'Broad St & Bridge St', 'Park Ave & St Edwards St',
#        'Prospect Park West & 8 St', 'Bond St & Fulton St',
#        'St James Pl & Pearl St', 'Cumberland St & Lafayette Ave',
#        'W 106 St & Central Park West', 'E 61 St & Park Ave',
#        '3 St & Hoyt St', 'Amsterdam Ave & W 66 St',
#        'Washington Ave & Park Ave', '21 St & Queens Plaza North',
#        'Milton St & Franklin St', 'E 44 St & 2 Ave',
#        'Hope St & Union Ave', 'Leonard St & Boerum St',
#        'India St & Manhattan Ave', 'Carroll St & Columbia St',
#        'Atlantic Ave & Fort Greene Pl', 'Washington Ave & Greene Ave',
#        'Sigourney St & Columbia St', 'Clinton Ave & Flushing Ave',
#        'Railroad Ave & Kay Ave', 'Schermerhorn St & Court St',
#        '10 St & 5 Ave', 'Pearl St & Anchorage Pl', 'Carroll St & 6 Ave',
#        'E 68 St & 3 Ave', 'Lefferts Pl & Franklin Ave',
#        'Columbia St & W 9 St', 'Kane St & Clinton St',
#        'Division Ave & Marcy Ave', 'Franklin St & W Broadway',
#        'E 110 St & Madison Ave', 'Myrtle Ave & St Edwards St',
#        'E 89 St & 3 Ave', 'Kent Ave & S 11 St', '7 St & 5 Ave',
#        'Douglass St & 3 Ave', 'W 89 St & Columbus Ave',
#        'Riverside Blvd & W 67 St', 'Monroe St & Tompkins Ave',
#        'W 107 St & Columbus Ave', '4 Ave & 2 St',
#        'E 106 St & Lexington Ave', 'Greenpoint Ave & Manhattan Ave',
#        'Bayard St & Leonard St', 'Market St & Cherry St',
#        'Fulton St & Utica Ave', 'Columbia St & Lorraine St',
#        'Old Slip & Front St', 'E 76 St & Park Ave',
#        'Columbus Ave & W 95 St', 'Berry St & N 8 St',
#        'Center Blvd & Borden Ave', '5 St & 6 Ave',
#        'DeKalb Ave & Vanderbilt Ave', 'Devoe St & Lorimer St',
#        'Willoughby Ave & Walworth St', 'Wolcott St & Dwight St',
#        'W 54 St & 9 Ave', 'Broadway & Whipple St',
#        'Riverside Dr & W 89 St', 'Washington Park',
#        'E 103 St & Lexington Ave', 'E 53 St & 3 Ave',
#        'Park Ave & Marcus Garvey Blvd', 'Cambridge Pl & Gates Ave',
#        'Court St & Nelson St', '6 St & 7 Ave', 'Stagg St & Union Ave',
#        'Nassau St & Navy St', 'Riverside Dr & W 82 St', '4 Ave & 9 St',
#        'Franklin Ave & Myrtle Ave', '46 Ave & 5 St', '48 Ave & 5 St',
#        'Lewis Ave & Kosciuszko St', 'Greene Ave & Throop Ave',
#        '10 St & 7 Ave', '2 Ave & 9 St', 'Nostrand Ave & Myrtle Ave',
#        'Bergen St & Flatbush Ave', 'Kosciuszko St & Tompkins Ave',
#        'Johnson St & Gold St', 'N 15 St & Wythe Ave', '10 Hudson Yards',
#        'Industry City, Building 1 Basement', 'Pacific St & Nevins St',
#        'Putnam Ave & Nostrand Ave', 'Monroe St & Bedford Ave',
#        'Greene Ave & Nostrand Ave', 'Hoyt St & Warren St',
#        'Adventures NYC', 'Myrtle Ave & Marcy Ave',
#        'Pioneer St & Richards St', 'Madison Ave & E 99 St',
#        'Lafayette Ave & Classon Ave', 'Lorimer St & Broadway',
#        'E 53 St & Lexington Ave', 'Clinton St & Centre St',
#        '6 Ave & 9 St', 'N 12 St & Bedford Ave', 'Jackson St & Leonard St',
#        'Douglass St & 4 Ave', 'E 74 St & 1 Ave', 'E 43 St & 2 Ave',
#        'E 82 St & East End Ave', 'E 97 St & 3 Ave',
#        'Fulton St & Grand Ave', 'Congress St & Clinton St',
#        '21 St & 43 Ave', 'DeKalb Ave & Skillman St',
#        'Penn Station Valet - Valet Scan', 'Pitt St & Stanton St',
#        '14 St & 5 Ave', 'India St & West St', 'Van Brunt St & Wolcott St',
#        'E 102 St & Park Ave', 'E 106 St & 1 Ave', 'Henry St & W 9 St',
#        'Dwight St & Van Dyke St', '3 Ave & E 100 St',
#        'Lewis Ave & Decatur St', '21 St & 41 Ave', '2 Ave  & E 104 St',
#        'NYCBS Depot - STY - Garage 4', 'McKibbin St & Manhattan Ave',
#        'Lewis Ave & Madison St', 'Reed St & Van Brunt St',
#        'E 109 St & 3 Ave', 'Pulaski St & Marcus Garvey Blvd',
#        'Humboldt St & Varet St', '9 St & 44 Rd', 'Soissons Landing',
#        '7 St & 3 Ave', '6 Ave & 12 St', 'Kingston Ave & Herkimer St',
#        'Marcy Ave & Lafayette Ave', 'E 106 St & Madison Ave',
#        'Coffey St & Conover St', 'W 15 St & 10 Ave',
#        'Bike The Branches - Central Branch', 'NYCBS Depot - STY',
C-73.9537575', '40.67892519999999%2C-74.0110495', '40.7127354%2C-73.9568145', '40.7295162%2C-73.9896108', '40.7359448%2C-73.9934533', '40.7220014%2C-74.0081909', '40.7923561%2C-73.9525283', '40.7571236%2C-73.9719337', '40.769058%2C-73.9611034', '40.7814422%2C-73.9561416', '40.6869907%2C-73.97664', '40.6830972%2C-73.97910159999999', '40.7355545%2C-73.95852099999999', '40.6864649%2C-73.9939237', '40.7130854%2C-73.9850225', '40.6682362%2C-73.9738301', '40.6877612%2C-74.00139700000001', '40.6958511%2C-73.9713951', '40.6751578%2C-73.9813228', '40.6784216%2C-74.0000537', '40.6802984%2C-73.9477306', '40.7045129%2C-74.01427819999999', '40.6829209%2C-73.99305749999999', '40.719153%2C-74.00210489999999', '40.7972581%2C-73.9700108', '40.7704169%2C-73.9876057', '40.7845154%2C-73.9498287', '40.75898309999999%2C-73.9624438', '40.72068489999999%2C-73.9782389', '40.7256146%2C-73.9444977', '40.7749468%2C-73.9447823', '40.7178259%2C-73.9476912', '40.73924299999999%2C-73.999185', '40.7521542%2C-73.9797854', '40.708625%2C-73.94512499999999', '40.7536365%2C-73.98713839999999', '40.69187609999999%2C-73.96561249999999', '40.6795146%2C-74.0076801', '40.7711473%2C-73.9639279', '40.7994175%2C-73.9552076', '40.6820673%2C-73.99086', '40.7327696%2C-73.9900294', '40.72441%2C-73.99586769999999', '40.7901959%2C-73.9769125', '40.7374771%2C-73.9746524', '40.7726606%2C-73.95555809999999', '40.6865121%2C-74.0168097', '40.7879037%2C-73.9536771', '40.7770003%2C-73.95965249999999', '40.7470974%2C-73.94231719999999', '40.677442%2C-73.98311389999999', '40.7095765%2C-74.0064331', '40.6825139%2C-73.94374499999999', '40.6857553%2C-74.0023549', '40.7110341%2C-73.9605947', '40.7752575%2C-73.9476255', '40.6711978%2C-73.9748413', '40.718924%2C-73.999231', '40.7453168%2C-73.9868504', '40.7516622%2C-73.9926747', '40.6961917%2C-73.99122059999999', '40.7800156%2C-73.9769214', '40.7747467%2C-73.9881778', '40.695 ...

# %% [markdown]
# # Looped through lat/long array and called Google Nearby Search to get establishments within 270ft of the bike hub.
#
# ## put that information into a dataframe with lat_long_key as a potential primary key
#
# ## created a new dataframe for analysis

# %%
full_json = []
full_json_append =[]
count_nearby_calls = 0
count_places = 0

for x in lat_long_compiled:
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+x+"&name&radius=270&type=bar&key=D....FHPvYeDKi1C86IRM"
    nearbyResponse = requests.request("GET", url)
    f = open("Bikshare_PlacesNearby_Responses.txt", "a")
    f.write(nearbyResponse.text)
    f.write("\n")
    f.close()
    nearbyResponse_json = nearbyResponse.json()
    for y in range(len(nearbyResponse_json['results'])):
        nearbyResponse_json['results'][y]['lat_long_key'] = x
        nearbyResponse_json['results'][y]['Start Station'] = listOfStartStations[lat_long_compiled.index(x)]

        full_json.append(nearbyResponse_json['results'][y])
#         full_json_append.append(nearbyResponse_json['results'][y])
        count_places += 1
    count_nearby_calls += 1
nearby_df = pd.json_normalize(full_json)
nearby_df.head()
# Out:
#   business_status                                               icon  \
# 0     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#   icon_background_color                                 icon_mask_base_uri  \
# 0               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                 name                                             photos  \
# 0  Please Don't Tell  [{'height': 3413, 'html_attributions': ['<a hr...
# 1       Cafe Mogador  [{'height': 3456, 'html_attributions': ['<a hr...
# 2             Kazuza  [{'height': 4032, 'html_attributions': ['<a hr...
# 3        Sahara East  [{'height': 1924, 'html_attributions': ['<a hr...
# 4          La Palapa  [{'height': 3024, 'html_attributions': ['<a hr...
#
#                       place_id  price_level  rating  \
# 0  ChIJb67-ZZ1ZwokRRxBYr3GlFp0          3.0     4.3
# 1  ChIJK48-E51ZwokRvAA-v6fx9y0          2.0     4.5
# 2  ChIJg3MwTp1ZwokRR09egp9Xo-c          2.0     4.1
# 3  ChIJn1VL7J1ZwokRYSF8iqTh8Go          1.0     4.1
# 4  ChIJv-yiA51ZwokRfkf4YagKlPs          2.0     4.2
#
#                      reference  ... geometry.location.lat  \
# 0  ChIJb67-ZZ1ZwokRRxBYr3GlFp0  ...             40.727137
# 1  ChIJK48-E51ZwokRvAA-v6fx9y0  ...             40.727431
# 2  ChIJg3MwTp1ZwokRR09egp9Xo-c  ...             40.725937
# 3  ChIJn1VL7J1ZwokRYSF8iqTh8Go  ...             40.729455
# 4  ChIJv-yiA51ZwokRfkf4YagKlPs  ...             40.727868
#
#   geometry.location.lng  geometry.viewport.northeast.lat  \
# 0            -73.983741                        40.728409
# 1            -73.984311                        40.728676
# 2            -73.983789                        40.727269
# 3            -73.983696                        40.730840
# 4            -73.985663                        40.729161
#
#   geometry.viewport.northeast.lng geometry.viewport.southwest.lat  \
# 0                      -73.982443                       40.725711
# 1                      -73.983037                       40.725978
# 2                      -73.982364                       40.724571
# 3                      -73.982444                       40.728142
# 4                      -73.984314                       40.726463
#
#   geometry.viewport.southwest.lng  opening_hours.open_now  \
# 0                      -73.985141                    True
# 1                      -73.985735                   False
# 2                      -73.985062                    True
# 3                      -73.985142                    True
# 4                      -73.987012                   False
#
#      plus_code.compound_code  plus_code.global_code  permanently_closed
# 0  P2G8+VG New York, NY, USA            87G8P2G8+VG                 NaN
# 1  P2G8+X7 New York, NY, USA            87G8P2G8+X7                 NaN
# 2  P2G8+9F New York, NY, USA            87G8P2G8+9F                 NaN
# 3  P2H8+QG New York, NY, USA            87G8P2H8+QG                 NaN
# 4  P2H7+4P New York, NY, USA            87G8P2H7+4P                 NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # data analysis of nearby establishments
# ### There are 2513 bars restaurants and nightclubs within 1 block of bike hubs
# ### President St & Henry St has the most establishments nearby (40) and an avg price level of 2.11

# %%
nearby_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2513 entries, 0 to 2512
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   business_status                  2513 non-null   object
#  1   icon                             2513 non-null   object
#  2   icon_background_color            2513 non-null   object
#  3   icon_mask_base_uri               2513 non-null   object
#  4   name                             2513 non-null   object
#  5   photos                           2394 non-null   object
#  6   place_id                         2513 non-null   object
#  7   price_level                      1765 non-null   float64
#  8   rating                           2403 non-null   float64
#  9   reference                        2513 non-null   object
#  10  scope                            2513 non-null   object
#  11  types                            2513 non-null   object
#  12  user_ratings_total               2403 non-null   float64
#  13  vicinity                         2513 non-null   object
#  14  lat_long_key                     2513 non-null   object
#  15  Start Station                    2513 non-null   object
#  16  geometry.location.lat            2513 non-null   float64
#  17  geometry.location.lng            2513 non-null   float64
#  18  geometry.viewport.northeast.lat  2513 non-null   float64
#  19  geometry.viewport.northeast.lng  2513 non-null   float64
#  20  geometry.viewport.southwest.lat  2513 non-null   float64
#  21  geometry.viewport.southwest.lng  2513 non-null   float64
#  22  opening_hours.open_now           2250 non-null   object
#  23  plus_code.compound_code          2513 non-null   object
#  24  plus_code.global_code            2513 non-null   object
#  25  permanently_closed               180 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 510.6+ KB

# %%
nearby_df['Start Station'].mode()
# Out:
# 0    President St & Henry St
# dtype: object

# %%
nearby_df[nearby_df['Start Station'] == 'President St & Henry St'].count()
# Out:
# business_status                    40
# icon                               40
# icon_background_color              40
# icon_mask_base_uri                 40
# name                               40
# photos                             36
# place_id                           40
# price_level                        36
# rating                             34
# reference                          40
# scope                              40
# types                              40
# user_ratings_total                 34
# vicinity                           40
# lat_long_key                       40
# Start Station                      40
# geometry.location.lat              40
# geometry.location.lng              40
# geometry.viewport.northeast.lat    40
# geometry.viewport.northeast.lng    40
# geometry.viewport.southwest.lat    40
# geometry.viewport.southwest.lng    40
# opening_hours.open_now             34
# plus_code.compound_code            40
# plus_code.global_code              40
# permanently_closed                  6
# dtype: int64

# %%
pres_hen_df = nearby_df[nearby_df['Start Station'] == 'President St & Henry St']
pres_hen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 1286 to 2314
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   business_status                  40 non-null     object
#  1   icon                             40 non-null     object
#  2   icon_background_color            40 non-null     object
#  3   icon_mask_base_uri               40 non-null     object
#  4   name                             40 non-null     object
#  5   photos                           36 non-null     object
#  6   place_id                         40 non-null     object
#  7   price_level                      36 non-null     float64
#  8   rating                           34 non-null     float64
#  9   reference                        40 non-null     object
#  10  scope                            40 non-null     object
#  11  types                            40 non-null     object
#  12  user_ratings_total               34 non-null     float64
#  13  vicinity                         40 non-null     object
#  14  lat_long_key                     40 non-null     object
#  15  Start Station                    40 non-null     object
#  16  geometry.location.lat            40 non-null     float64
#  17  geometry.location.lng            40 non-null     float64
#  18  geometry.viewport.northeast.lat  40 non-null     float64
#  19  geometry.viewport.northeast.lng  40 non-null     float64
#  20  geometry.viewport.southwest.lat  40 non-null     float64
#  21  geometry.viewport.southwest.lng  40 non-null     float64
#  22  opening_hours.open_now           34 non-null     object
#  23  plus_code.compound_code          40 non-null     object
#  24  plus_code.global_code            40 non-null     object
#  25  permanently_closed               6 non-null      object
# dtypes: float64(9), object(17)
# memory usage: 8.4+ KB

# %%
pres_hen_df['price_level'].mean()
# Out:
# 2.111111111111111

# %%
y.keys()
# Out:
# dict_keys(['business_status', 'geometry', 'icon', 'icon_background_color', 'icon_mask_base_uri', 'name', 'opening_hours', 'photos', 'place_id', 'plus_code', 'rating', 'reference', 'scope', 'types', 'user_ratings_total', 'vicinity'])
